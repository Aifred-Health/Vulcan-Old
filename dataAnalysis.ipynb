# %%
import pandas as pd
import numpy as np
import collections as cnt
data = pd.read_csv('Citalopram_study.csv',low_memory='false',header = None,
                  index_col=0)
#data = np.array(data)
data = data.transpose()
del data['Response']
del data['Remission']
del data['FileGroup']
del data['Accession Id']
del data['TimePoint']
del data['(ng/ml/mg CIT dose)']
del data['%improvement']
numPatients = np.count_nonzero(pd.unique(data.values[:,0]))
numAttributes = np.count_nonzero(pd.unique(data.values[0]))

# %%
data2 = pd.read_csv('Duloxetine_study.csv',low_memory='false',header = None,
                  index_col=0)
data2 = data2.transpose()
del data2['response']
del data2['remission']
del data2['ID_complet']
del data2['num']
del data2['id partiel']
del data2['id ']
numPatients2 = np.count_nonzero(pd.unique(data2.values[:,0]))
numAttributes2 = np.count_nonzero(pd.unique(data2.values[0]))

# %%
np.count_nonzero(pd.unique(data2['study']))
# Out:
# 3

# %%
numPatients2
# Out:
# 112

# %%
numAttributes2
# Out:
# 16616

# %%
data2
# Out:
# 0             ID Sex   study age   race MARDS_T0 MARST8     %  RIN taille  \
# 1    126_GTI1802   M  11984A  30  White       37     22   59%  8,3    178
# 2    130_GTI1848   F  11984A  60  White       29     20   69%    8    161
# 3    132_GTI1846   F  11984A  43  White       36     26   72%  8,5    163
# 4    190_GTI1551   M  13267A  31  White       31     26   84%  6,8    185
# 5    191_GTI1545   F  13267A  51  White       31     26   84%    8    158
# 6    218_GTI1558   M  13267A  72  White       31     20   65%  8,3    174
# 7    230_GTI1468   F  13267A  49  White       30     27   90%  8,8    168
# 8    291_GTI1670   F  13267A  53  White       34     22   65%  5,2    169
# 9    318_GTI1647   F  13267A  21  White       26     37  142%  8,9  161,5
# 10   320_GTI1560   F  13267A  57  White       29     22   76%  8,7    174
# 11   340_GTI1480   M  13267A  40  White       34     28   82%  9,1    175
# 12   352_GTI1702   F  13267A  50  White       33     19   58%  7,1    158
# ...
